// %% [markdown]
// **Welcome**
// Welcome to COMP 1010 on Jupyter Notebooks.
// Follow along through this notebook and complete the activities with a partner. Only one of you should be logged in. But, when noted, switch which person is doing the typing.
// Let's get started! In the block below is a Processing program. There is already a line of code there that draws a rectangle. Run the code by clickin in the cell, and hitting the run button in the toolbar at the top.

// %%
size(300,300);
background(0);
rect(50, 50, 200, 100);
// Out:
// <div id="canvas_div_5">
//   <b>Sketch #5:</b><br/>
//   <canvas id="canvas_5"></canvas><br/>
// </div>
// <div id="controls_div_5">
//   <button id="run_button_5" onclick="startSketch('5');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_5" onclick="pauseSketch('5');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_5" onclick="setupSketch('5');">
//     setup()
//   </button>
//   <button id="draw_button_5" onclick="drawSketch('5');">
//     draw()
//   </button>
// </div>
// <b>Sketch #5 state:</b> <span id="state_5">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// You should see an image above that is a black rectangle with a smaller white rectangle inside. Like this:
//
// <img src="Images/week2_ex1.png" width="300"/>
//
// Now, this is the beginning of a robot. It's just the robot's head. Your job is to write some code to change the robot. First, give the robot a left eye. In the code cell below, add an ellipse command after the rect command. The ellipse takes 4 parameters (pieces of information separated by commas): the x and y coordinates for where you want the ellipse to be centered, and the width and height of the ellipse. So, to create circle eyes, the width and height should be the same. Try to make the robot head with the left eye look like this:
//
// <img src="Images/week2_ex2.png" width="300"/>

// %%
size(300,300);
background(0);
rect(50, 50, 200, 100);
// write code below here to add a left eye
// then click the Run button at the top
// it may take a few trys to get the right numbers to 
// get the eye the right size and in the right place
// Out:
// <div id="canvas_div_6">
//   <b>Sketch #6:</b><br/>
//   <canvas id="canvas_6"></canvas><br/>
// </div>
// <div id="controls_div_6">
//   <button id="run_button_6" onclick="startSketch('6');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_6" onclick="pauseSketch('6');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_6" onclick="setupSketch('6');">
//     setup()
//   </button>
//   <button id="draw_button_6" onclick="drawSketch('6');">
//     draw()
//   </button>
// </div>
// <b>Sketch #6 state:</b> <span id="state_6">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...
