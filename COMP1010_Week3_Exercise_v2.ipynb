// %% [markdown]
// **Week 3**
//
// **Beware that this notebook will expire after 10 minutes of inactivity**
//
// **If it seems like the notebook isn't responding, try Kernel->Restart or Kernel->Reconnect**
//
// **Keep working and frequently save using the save button at the top (don't use Save as...)**

// %% [markdown]
// Work with **1** partner (not in threes and not by yourself!).
//
// Type your names here: (double-click in this cell to make it editable). This cell uses Markdown so you can make things **bold** or *italic*. When you are done editing this cell, click Run to see your formatting.
//
//     Student 1:
//     Student 2:

// %% [markdown]
// **Step 1 - Robot resizable!**
//
// Let's get started! In the block below is Dr. Celine's robot head from Week 2. Run this to see what the robot looks like. Change the canvas size() and run it again to make sure the robot resizes appropriately.

// %%
/** 
Dr. Celine's Robot Head
**/
// global vars
size(500,500);
int headWidth = width*2/3;
int headHeight = height/3;
int headTop = (height - headHeight)/3;
int headLeft = (width - headWidth)/2;

int leftEyeX = headLeft + headWidth/4;
int rightEyeX = headLeft + headWidth*3/4;
int eyeY = headTop + headHeight/3;
int eyeDiam = headWidth/5;
int eyeBallDiam = eyeDiam/2;

int mouthLeft = leftEyeX;
int mouthRight = rightEyeX;
int mouthY = headTop + headHeight*3/4;


background(100, 100, 250);

// draw head
fill(200, 200, 50);
rect(headLeft, headTop, headWidth, headHeight);

// draw eyes
fill(255);
ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

// draw eyeballs
fill(0);
ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


// draw mouth
stroke(200, 100, 100);
strokeWeight(8);
line(mouthLeft, mouthY, mouthRight, mouthY);
// Out:
// <div id="canvas_div_19">
//   <b>Sketch #19:</b><br/>
//   <canvas id="canvas_19"></canvas><br/>
// </div>
// <div id="controls_div_19">
//   <button id="run_button_19" onclick="startSketch('19');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_19" onclick="pauseSketch('19');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_19" onclick="setupSketch('19');">
//     setup()
//   </button>
//   <button id="draw_button_19" onclick="drawSketch('19');">
//     draw()
//   </button>
// </div>
// <b>Sketch #19 state:</b> <span id="state_19">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 2 - Turn this into an active Processing script**
//
// Turn this into an Active processing script by putting the size() command in a setup() function and the drawing functions in a draw() function. Note that you are going to have to put variable declarations as globals at the top, and then initialize all the variable values inside setup(). Once you have done this, run the program to make sure you still see the same robot.

// %%
// global vars
size(500,500);
int headWidth = width*2/3;
int headHeight = height/3;
int headTop = (height - headHeight)/3;
int headLeft = (width - headWidth)/2;

int leftEyeX = headLeft + headWidth/4;
int rightEyeX = headLeft + headWidth*3/4;
int eyeY = headTop + headHeight/3;
int eyeDiam = headWidth/5;
int eyeBallDiam = eyeDiam/2;

int mouthLeft = leftEyeX;
int mouthRight = rightEyeX;
int mouthY = headTop + headHeight*3/4;


background(100, 100, 250);

// draw head
fill(200, 200, 50);
rect(headLeft, headTop, headWidth, headHeight);

// draw eyes
fill(255);
ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

// draw eyeballs
fill(0);
ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


// draw mouth
stroke(200, 100, 100);
strokeWeight(8);
line(mouthLeft, mouthY, mouthRight, mouthY);
// Out:
// <div id="canvas_div_18">
//   <b>Sketch #18:</b><br/>
//   <canvas id="canvas_18"></canvas><br/>
// </div>
// <div id="controls_div_18">
//   <button id="run_button_18" onclick="startSketch('18');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_18" onclick="pauseSketch('18');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_18" onclick="setupSketch('18');">
//     setup()
//   </button>
//   <button id="draw_button_18" onclick="drawSketch('18');">
//     draw()
//   </button>
// </div>
// <b>Sketch #18 state:</b> <span id="state_18">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 3 - Add interaction**
//
// Make your script better by adding a moving circle that follows the mouse cursor, in front of the robot. Copy your code from above, and add the following two global int variables, flyWidth and flyHeight, both intialized to 20. In setup() initialize these both to 0. Also add flyX and flyY. In the setup() code initialize these to be at the center of the canvas (use width and height).
//
// In the draw() funtion, after the commands that draw the robot face, add the following code to draw a buzzing fly that moves randomly around the screen (we'll learn about max() and random() next week, which is why I'm giving you the code this week).
//
//     // draw fly
//     stroke(0);
//     strokeWeight(1);
//     fill(125);
//     flyX = max(0,(flyX + random(20)-10)%width);
//     flyY = max(0,(flyY + random(20)-10)%height);
//     ellipse(flyX, flyY, flyWidth, flyHeight);
//
//     // fly eyes
//     fill(0);
//     stroke(255);
//     ellipse(flyX-flyWidth/3, flyY - flyHeight/2, 5, 5);
//     ellipse(flyX+flyWidth/3, flyY - flyHeight/2, 5, 5);
//
//     // fly wings
//     fill(200);
//     noStroke();
//     ellipse(flyX-flyWidth/2, flyY, 10, 5);
//     ellipse(flyX+flyWidth/2, flyY, 10, 5);
//
// Note that everything in this code is relative to the flyX and flyY variables.
// Run the code to see the fly buzzing around.

// %%
// global vars


int headWidth;
int headHeight;
int headTop;
int headLeft;

int leftEyeX;
int rightEyeX;
int eyeY;
int eyeDiam;
int eyeBallDiam;

int mouthLeft;
int mouthRight;
int mouthY;

int flyWidth;
int flyHeight;
int flyX;
int flyY;

void setup() {
size(500,500);
    headWidth = width*2/3;
    headHeight = height/3;
    headTop = (height - headHeight)/3;
    headLeft = (width - headWidth)/2;

    leftEyeX = headLeft + headWidth/4;
    rightEyeX = headLeft + headWidth*3/4;
    eyeY = headTop + headHeight/3;
    eyeDiam = headWidth/5;
    eyeBallDiam = eyeDiam/2;

    mouthLeft = leftEyeX;
    mouthRight = rightEyeX;
    mouthY = headTop + headHeight*3/4;
    
    flyWidth = 20;
    flyHeight = 10;
    flyX = width/2;
    flyY = height/2;
}

void draw() {
    background(100, 100, 250);

    // draw head
    fill(200, 200, 50);
    rect(headLeft, headTop, headWidth, headHeight);

    // draw eyes
    fill(255);
    ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

    // draw eyeballs
    fill(0);
    ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


    // draw mouth
    stroke(200, 100, 100);
    strokeWeight(8);
    line(mouthLeft, mouthY, mouthRight, mouthY);

    // draw fly
    stroke(0);
    strokeWeight(1);
    fill(125);
    flyX = max(0,(flyX + random(20)-10)%width);
    flyY = max(0,(flyY + random(20)-10)%height);
    ellipse(flyX, flyY, flyWidth, flyHeight);
    // fly eyes
    fill(0);
    stroke(255);
    ellipse(flyX-flyWidth/3, flyY - flyHeight/2, 5, 5);
    ellipse(flyX+flyWidth/3, flyY - flyHeight/2, 5, 5);
    // fly wings
    fill(200);
    noStroke();
    ellipse(flyX-flyWidth/2, flyY, 10, 5);
    ellipse(flyX+flyWidth/2, flyY, 10, 5);
    
}
// Out:
// <div id="canvas_div_20">
//   <b>Sketch #20:</b><br/>
//   <canvas id="canvas_20"></canvas><br/>
// </div>
// <div id="controls_div_20">
//   <button id="run_button_20" onclick="startSketch('20');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_20" onclick="pauseSketch('20');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_20" onclick="setupSketch('20');">
//     setup()
//   </button>
//   <button id="draw_button_20" onclick="drawSketch('20');">
//     draw()
//   </button>
// </div>
// <b>Sketch #20 state:</b> <span id="state_20">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 4 - Put fly in a function!**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// Copy the code from above into the cell below. Create a function called robotFace(). This function returns nothing and takes no parameters. Put it below the draw function,  and move the code that draws the robot into this function. Then create a function called drawFly() and move the code that draws the fly into that function. Finally, call the drawRobot and drawFly function from inside draw().
//
// Run your code to make sure it still works.

// %%
// copy code from above to this cell.
// Then put the fly drawing code in a function called drawFly()
// and the robot drawing stuff into a function called drawRobot()
// global vars


int headWidth;
int headHeight;
int headTop;
int headLeft;

int leftEyeX;
int rightEyeX;
int eyeY;
int eyeDiam;
int eyeBallDiam;

int mouthLeft;
int mouthRight;
int mouthY;

int flyWidth;
int flyHeight;
int flyX;
int flyY;

void setup() {
size(500,500);
    headWidth = width*2/3;
    headHeight = height/3;
    headTop = (height - headHeight)/3;
    headLeft = (width - headWidth)/2;

    leftEyeX = headLeft + headWidth/4;
    rightEyeX = headLeft + headWidth*3/4;
    eyeY = headTop + headHeight/3;
    eyeDiam = headWidth/5;
    eyeBallDiam = eyeDiam/2;

    mouthLeft = leftEyeX;
    mouthRight = rightEyeX;
    mouthY = headTop + headHeight*3/4;
    
    flyWidth = 20;
    flyHeight = 10;
    flyX = width/2;
    flyY = height/2;
}

void draw() {
    background(100, 100, 250);
    drawRobot();
    drawFly();
}

void drawRobot() {
    // draw head
    fill(200, 200, 50);
    rect(headLeft, headTop, headWidth, headHeight);

    // draw eyes
    fill(255);
    ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

    // draw eyeballs
    fill(0);
    ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


    // draw mouth
    stroke(200, 100, 100);
    strokeWeight(8);
    line(mouthLeft, mouthY, mouthRight, mouthY);
}

void drawFly() {
    // draw fly
    stroke(0);
    strokeWeight(1);
    fill(125);
    flyX = max(0,(flyX + random(20)-10)%width);
    flyY = max(0,(flyY + random(20)-10)%height);
    ellipse(flyX, flyY, flyWidth, flyHeight);
    // fly eyes
    fill(0);
    stroke(255);
    ellipse(flyX-flyWidth/3, flyY - flyHeight/2, 5, 5);
    ellipse(flyX+flyWidth/3, flyY - flyHeight/2, 5, 5);
    // fly wings
    fill(200);
    noStroke();
    ellipse(flyX-flyWidth/2, flyY, 10, 5);
    ellipse(flyX+flyWidth/2, flyY, 10, 5);
    
}
// Out:
// <div id="canvas_div_21">
//   <b>Sketch #21:</b><br/>
//   <canvas id="canvas_21"></canvas><br/>
// </div>
// <div id="controls_div_21">
//   <button id="run_button_21" onclick="startSketch('21');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_21" onclick="pauseSketch('21');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_21" onclick="setupSketch('21');">
//     setup()
//   </button>
//   <button id="draw_button_21" onclick="drawSketch('21');">
//     draw()
//   </button>
// </div>
// <b>Sketch #21 state:</b> <span id="state_21">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 5 - Make the eyes follow the fly!**
//
// We want to have the robot's eyeballs move towards wherever the fly is.
//
// **5a** For each eyeball, we need to separate out the x and y (right now the eyes and the eyeballs are both controlled by the three variables leftEyeX, rightEyeX and eyeY.) Create four more global variables called leftEBX, leftEBY, rightEBX, rightEBY. In the setup function, set these equal to the same values they were before (assigning from leftEyeX, rightEyeX and eyeY).
//
// **5b** In the ellipse commands that draw the eyeballs, make use of the four new variables for the eyeball positions. Run the robot code to make sure that the eyeballs are still centered (we make them move in the next step).
//
// **5c**

// %%
// copy code from above to this cell
// add new vars for the position of the eyeBalls

// copy code from above to this cell.
// Then put the fly drawing code in a function called drawFly()
// and the robot drawing stuff into a function called drawRobot()
// global vars


int headWidth;
int headHeight;
int headTop;
int headLeft;

int leftEyeX;
int rightEyeX;
int eyeY;
int eyeDiam;
int eyeBallDiam;
int leftEBX, leftEBY;
int rightEBX, rightEBY;

int mouthLeft;
int mouthRight;
int mouthY;

int flyWidth;
int flyHeight;
int flyX;
int flyY;

void setup() {
    size(500,500);
    headWidth = width*2/3;
    headHeight = height/3;
    headTop = (height - headHeight)/3;
    headLeft = (width - headWidth)/2;

    leftEyeX = headLeft + headWidth/4;
    rightEyeX = headLeft + headWidth*3/4;
    eyeY = headTop + headHeight/3;
    eyeDiam = headWidth/5;
    eyeBallDiam = eyeDiam/2;
    leftEBX = leftEyeX;
    rightEBX = rightEyeX;
    leftEBY = eyeY;
    rightEBY = eyeY;

    mouthLeft = leftEyeX;
    mouthRight = rightEyeX;
    mouthY = headTop + headHeight*3/4;
    
    flyWidth = 20;
    flyHeight = 10;
    flyX = width/2;
    flyY = height/2;
}

void draw() {
    background(100, 100, 250);
    drawRobot();
    drawFly();
}

void drawRobot() {
    // draw head
    fill(200, 200, 50);
    rect(headLeft, headTop, headWidth, headHeight);

    // draw eyes
    fill(255);
    ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

    // draw eyeballs
    int lXdiff = flyX - leftEBX;
    int lYdiff = flyY - leftEBY;
    int rXdiff = flyX - rightEBX;
    int rYdiff = flyY - rightEBY;
    leftEBX = (leftEyeX + lXdiff/10);
    leftEBY = (eyeY + lYdiff/10);
    rightEBX = (rightEyeX + rXdiff/10);
    rightEBY = (eyeY + rYdiff/10);
    fill(0);
    ellipse(leftEBX, leftEBY, eyeBallDiam, eyeBallDiam); // left eye
    ellipse(rightEBX, rightEBY, eyeBallDiam, eyeBallDiam); // right eye


    // draw mouth
    stroke(200, 100, 100);
    strokeWeight(8);
    line(mouthLeft, mouthY, mouthRight, mouthY);
}

void drawFly() {
    // draw fly
    stroke(0);
    strokeWeight(1);
    fill(125);
    flyX = max(0,(flyX + random(20)-10)%width);
    flyY = max(0,(flyY + random(20)-10)%height);
    ellipse(flyX, flyY, flyWidth, flyHeight);
    // fly eyes
    fill(0);
    stroke(255);
    ellipse(flyX-flyWidth/3, flyY - flyHeight/2, 5, 5);
    ellipse(flyX+flyWidth/3, flyY - flyHeight/2, 5, 5);
    // fly wings
    fill(200);
    noStroke();
    ellipse(flyX-flyWidth/2, flyY, 10, 5);
    ellipse(flyX+flyWidth/2, flyY, 10, 5);
    
}
// Out:
// <div id="canvas_div_17">
//   <b>Sketch #17:</b><br/>
//   <canvas id="canvas_17"></canvas><br/>
// </div>
// <div id="controls_div_17">
//   <button id="run_button_17" onclick="startSketch('17');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_17" onclick="pauseSketch('17');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_17" onclick="setupSketch('17');">
//     setup()
//   </button>
//   <button id="draw_button_17" onclick="drawSketch('17');">
//     draw()
//   </button>
// </div>
// <b>Sketch #17 state:</b> <span id="state_17">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 6 - CHANGE COLORS OVER TIME**
//
// Copy the code above into the cell below.
// Add a global variable for the amount of blue, called blueVal.
// In setup() initialize this to 0.
// In draw(), use blueVal in the background, instead of the 250 that is there now.
//
// Now, we want to add a tiny bit of blue, really slowly. We could add one to blueVal, everytime we run draw, by adding something like blueVal = blueVal + 1; above the background() command. Try this and see what happens.
//
// After awhile, the background doesn't get any more blue. Use the mod operator to cycle the blueVal continuously between 0 and 255 (the max value that makes any sense).

// %%
//copy code from above and then add and then play with a slowly changing background color
int headWidth;
int headHeight;
int headTop;
int headLeft;

int leftEyeX;
int rightEyeX;
int eyeY;
int eyeDiam;
int eyeBallDiam;
int leftEBX, leftEBY;
int rightEBX, rightEBY;

int mouthLeft;
int mouthRight;
int mouthY;

int flyWidth;
int flyHeight;
int flyX;
int flyY;

int blueVal;

void setup() {
    size(500,500);
    headWidth = width*2/3;
    headHeight = height/3;
    headTop = (height - headHeight)/3;
    headLeft = (width - headWidth)/2;

    leftEyeX = headLeft + headWidth/4;
    rightEyeX = headLeft + headWidth*3/4;
    eyeY = headTop + headHeight/3;
    eyeDiam = headWidth/5;
    eyeBallDiam = eyeDiam/2;
    leftEBX = leftEyeX;
    rightEBX = rightEyeX;
    leftEBY = eyeY;
    rightEBY = eyeY;

    mouthLeft = leftEyeX;
    mouthRight = rightEyeX;
    mouthY = headTop + headHeight*3/4;
    
    flyWidth = 20;
    flyHeight = 10;
    flyX = width/2;
    flyY = height/2;
    
    blueVal = 0;
}

void draw() {
    blueVal = (blueVal + 1)%256;
    background(100, 100, blueVal);
    drawRobot();
    drawFly();
}

void drawRobot() {
    // draw head
    fill(200, 200, 50);
    rect(headLeft, headTop, headWidth, headHeight);

    // draw eyes
    fill(255);
    ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

    // draw eyeballs
    int lXdiff = flyX - leftEBX;
    int lYdiff = flyY - leftEBY;
    int rXdiff = flyX - rightEBX;
    int rYdiff = flyY - rightEBY;
    leftEBX = (leftEyeX + lXdiff/10);
    leftEBY = (eyeY + lYdiff/10);
    rightEBX = (rightEyeX + rXdiff/10);
    rightEBY = (eyeY + rYdiff/10);
    fill(0);
    ellipse(leftEBX, leftEBY, eyeBallDiam, eyeBallDiam); // left eye
    ellipse(rightEBX, rightEBY, eyeBallDiam, eyeBallDiam); // right eye


    // draw mouth
    stroke(200, 100, 100);
    strokeWeight(8);
    line(mouthLeft, mouthY, mouthRight, mouthY);
}

void drawFly() {
    // draw fly
    stroke(0);
    strokeWeight(1);
    fill(125);
    flyX = max(0,(flyX + random(20)-10)%width);
    flyY = max(0,(flyY + random(20)-10)%height);
    ellipse(flyX, flyY, flyWidth, flyHeight);
    // fly eyes
    fill(0);
    stroke(255);
    ellipse(flyX-flyWidth/3, flyY - flyHeight/2, 5, 5);
    ellipse(flyX+flyWidth/3, flyY - flyHeight/2, 5, 5);
    // fly wings
    fill(200);
    noStroke();
    ellipse(flyX-flyWidth/2, flyY, 10, 5);
    ellipse(flyX+flyWidth/2, flyY, 10, 5);
    
}
// Out:
// <div id="canvas_div_16">
//   <b>Sketch #16:</b><br/>
//   <canvas id="canvas_16"></canvas><br/>
// </div>
// <div id="controls_div_16">
//   <button id="run_button_16" onclick="startSketch('16');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_16" onclick="pauseSketch('16');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_16" onclick="setupSketch('16');">
//     setup()
//   </button>
//   <button id="draw_button_16" onclick="drawSketch('16');">
//     draw()
//   </button>
// </div>
// <b>Sketch #16 state:</b> <span id="state_16">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 7 - ADD USER INTERAXCTION**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// Let's move the whole robot head towards the user's cursors.

// %%
//copy code from above and then edit it so the robot head moves to follow your cursor, 
// while the eyes keep following the fly

//copy code from above and then add and then play with a slowly changing background color
int headWidth;
int headHeight;
int headTop;
int headLeft;

int leftEyeX;
int rightEyeX;
int eyeY;
int eyeDiam;
int eyeBallDiam;
int leftEBX, leftEBY;
int rightEBX, rightEBY;

int mouthLeft;
int mouthRight;
int mouthY;

int flyWidth;
int flyHeight;
int flyX;
int flyY;

int blueVal;

void setup() {
    size(500,500);
    headWidth = width*2/3;
    headHeight = height/3;
    headTop = (height - headHeight)/3;
    headLeft = (width - headWidth)/2;


    
    flyWidth = 20;
    flyHeight = 10;
    flyX = width/2;
    flyY = height/2;
    
    blueVal = 0;
}

void draw() {
    blueVal = (blueVal + 1)%256;
    background(100, 100, blueVal);
    drawRobot();
    drawFly();
}

void drawRobot() {
    //int hXdiff = headLeft - mouseX;
    //int hYdiff = headTop - mouseY;
    headLeft = (mouseX - headWidth/2);
    headTop  = (mouseY - headHeight/2);
    // draw head
    fill(200, 200, 50);
    rect(headLeft, headTop, headWidth, headHeight);

    leftEyeX = headLeft + headWidth/4;
    rightEyeX = headLeft + headWidth*3/4;
    eyeY = headTop + headHeight/3;
    eyeDiam = headWidth/5;
    eyeBallDiam = eyeDiam/2;
    leftEBX = leftEyeX;
    rightEBX = rightEyeX;
    leftEBY = eyeY;
    rightEBY = eyeY;

    mouthLeft = leftEyeX;
    mouthRight = rightEyeX;
    mouthY = headTop + headHeight*3/4;
    // draw eyes
    fill(255);
    ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

    // draw eyeballs
    int lXdiff = flyX - leftEBX;
    int lYdiff = flyY - leftEBY;
    int rXdiff = flyX - rightEBX;
    int rYdiff = flyY - rightEBY;
    leftEBX = (leftEyeX + lXdiff/10);
    leftEBY = (eyeY + lYdiff/10);
    rightEBX = (rightEyeX + rXdiff/10);
    rightEBY = (eyeY + rYdiff/10);
    fill(0);
    ellipse(leftEBX, leftEBY, eyeBallDiam, eyeBallDiam); // left eye
    ellipse(rightEBX, rightEBY, eyeBallDiam, eyeBallDiam); // right eye


    // draw mouth
    stroke(200, 100, 100);
    strokeWeight(8);
    line(mouthLeft, mouthY, mouthRight, mouthY);
}

void drawFly() {
    // draw fly
    stroke(0);
    strokeWeight(1);
    fill(125);
    flyX = max(0,(flyX + random(20)-10)%width);
    flyY = max(0,(flyY + random(20)-10)%height);
    ellipse(flyX, flyY, flyWidth, flyHeight);
    // fly eyes
    fill(0);
    stroke(255);
    ellipse(flyX-flyWidth/3, flyY - flyHeight/2, 5, 5);
    ellipse(flyX+flyWidth/3, flyY - flyHeight/2, 5, 5);
    // fly wings
    fill(200);
    noStroke();
    ellipse(flyX-flyWidth/2, flyY, 10, 5);
    ellipse(flyX+flyWidth/2, flyY, 10, 5);
    
}
// Out:
// <div id="canvas_div_32">
//   <b>Sketch #32:</b><br/>
//   <canvas id="canvas_32"></canvas><br/>
// </div>
// <div id="controls_div_32">
//   <button id="run_button_32" onclick="startSketch('32');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_32" onclick="pauseSketch('32');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_32" onclick="setupSketch('32');">
//     setup()
//   </button>
//   <button id="draw_button_32" onclick="drawSketch('32');">
//     draw()
//   </button>
// </div>
// <b>Sketch #32 state:</b> <span id="state_32">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 8 - CONSTANTS!**
//
// Okay, so in actual fact, all of the things we have created so far are CONSTANTS, not variables. How do you know? Well, because each of them gets assigned only once during the program and the values don't change while the program is running.
//
// So, I hate to do this to you, but I want you to copy your program above, and add the keyword final in front of all your declarations, and change the code to be the correct style (ALL_CAPS). As an example, these:
//
//     int headHeight = height/3;
//
//     int headWidth = width\*2/3;
//
//     int headTop = (height - headHeight)/3;
//
//     int headLeft = (width - headWidth)/2;
//
// should be replaced by these:
//
//     final int HEAD_HEIGHT = height/3;
//
//     final int HEAD_WIDTH = width\*2/3;
//
//     final int HEAD_TOP = (height - HEAD_HEIGHT)/3;
//
//     final int HEAD_LEFT = (width - HEAD_WIDTH)/2;
//
// Once you are done making all the changes, run your code to make sure it is still working.

// %%
// copy above and change all your variables to CONSTANTS. Use appropriate capitalization. 
// You will have to change the variables throughout your code

// %% [raw]
// **Step 9 - COPY YOUR FINAL ROBOT IMAGE AND CODE TO YOUR TEAM WORKSPACE**
//
// Well, you are basically done. What do you do now? Save this notebook. I suggest downloading it as HTML. Your images will not show up, but all the code you wrote will be there and you will be able to see the progression of what you did.
//
// Once you have downloaded the HTML, upload the file to your team workspace on UMLearn. Alternatively, you can take screenshots and upload those to document your work. Make sure you add your names to the filename before uploading, so that when multiple people in your group add their's, you can differentiate.
//
// *You can also save it out as a Jupyter Notebook file (.ipynb), and if you install Jupyter notebooks, you can open that locally. (Note that installing Jupyter Notebooks is NOT easy at all - it's something for experienced sys admin type people, and may be well beyond your skill level - it took Dr. Celine awhile to get it working on her Mac).
