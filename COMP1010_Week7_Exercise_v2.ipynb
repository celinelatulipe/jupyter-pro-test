// %% [markdown]
// **Week 7**
//
// **Beware that this notebook will expire after 10 minutes of inactivity**
//
// **If it seems like the notebook isn't responding, try Kernel->Restart or Kernel->Reconnect**
//
// **Keep working and frequently copy your code out to an external text file in case the notebook instance disappears**
//
// Objectives:
//
// - Coding Practice!
// - While Loops

// %% [markdown]
// Work with **1** partner (not in threes and not by yourself!).
//
// Type your names here: (double-click in this cell to make it editable). This cell uses Markdown so you can make things **bold** or *italic*. When you are done editing this cell, click Run to see your formatting.
//
//     Student 1:
//     Student 2:

// %% [markdown]
// **Step 1 - COLLAPSING ELLIPSES**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// The code below draws a bunch of ellipses, each 1/9th the size of the previous. The code is super repetitive, and it only draws 4 ellipses.
//
// Your job is to change the code to use a while loop, and draw many ellipses, like this:
//
// <img src="images/collapsing_ellipses.png" width=300/>
//
// Step 1: create a constant that defines the width of the smallest ellipse you want to draw. Hint: you need to make sure the while loop doesn't draw forever, so think about, what is the size of the smallest ellipse you want to draw, and how can you use that in the while loop condition?
//
// Note that by using a while loop, you should be able to reduce the lines of code.

// %%
/* Collapsing ellispses
   Example for COMP 1010
*/
size(600,400);
background(255); // white
fill(255, 100, 100); // red
stroke(100, 100, 250); // blue
strokeWeight(1);
   
//Each ellipse is this proportion of the size of the previous one.
final float PROPORTION = 0.9;
  
//The variables controlling the ellipses.
float ellipseWidth=width;   //The whole window at first
float ellipseHeight=height; //Same here

ellipse(width/2,height/2,ellipseWidth,ellipseHeight);
ellipseWidth=ellipseWidth*PROPORTION;   // 90% of the size
ellipseHeight=ellipseHeight*PROPORTION; //in both directions

ellipse(width/2,height/2,ellipseWidth,ellipseHeight);
ellipseWidth=ellipseWidth*PROPORTION;   // 90% the size
ellipseHeight=ellipseHeight*PROPORTION; //in both directions

ellipse(width/2,height/2,ellipseWidth,ellipseHeight);
ellipseWidth=ellipseWidth*PROPORTION;   // 90% the size
ellipseHeight=ellipseHeight*PROPORTION; //in both directions

ellipse(width/2,height/2,ellipseWidth,ellipseHeight);
ellipseWidth=ellipseWidth*PROPORTION;   // 90% the size
ellipseHeight=ellipseHeight*PROPORTION; //in both directions
// Out:
// <div id="canvas_div_1">
//   <b>Sketch #1:</b><br/>
//   <canvas id="canvas_1"></canvas><br/>
// </div>
// <div id="controls_div_1">
//   <button id="run_button_1" onclick="startSketch('1');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_1" onclick="pauseSketch('1');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_1" onclick="setupSketch('1');">
//     setup()
//   </button>
//   <button id="draw_button_1" onclick="drawSketch('1');">
//     draw()
//   </button>
// </div>
// <b>Sketch #1 state:</b> <span id="state_1">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 2 - While Loop Clock Face**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// Complete the script below to draw a clock face.
//
// Here is an image that shows what it should look like.
//
// <img src="images/clock_face.png" width=300/>
//
// Test yours to make sure you did it right.

// %%
final int CLOCK_RADIUS = 100;
final int SMALL_DOT_DIAM = 5;
int centerX;
int centerY;

void setup() {
    size(500,500);
    centerX = width/2;
    centerY = height/2;
}

void draw() {
    background(0); //black
    drawClockFace();
}

void drawClockFace() {
    noFill();
    stroke(255); // white
    float angle = 0;
    
    /* TODO: put the following stuff into a WHILE loop. You need to draw 
        60 dots around the edge of the clock, not just one. 
        On each pass through the loop, the angle has to change so that 
        the dots aren't all in the same place. You'll need a counter variable to make
        sure that you loop through the correct number of times. */
    
    float clockDotX = centerX + cos(angle)*CLOCK_RADIUS;
    float clockDotY = centerY + sin(angle)*CLOCK_RADIUS;
    ellipse(clockDotX, clockDotY, SMALL_DOT_DIAM, SMALL_DOT_DIAM);
       
  
    /* NOTE: this clock center should NOT be in the while loop, 
        as it should only be drawn once. */
    // draw clock center point
    noStroke();
    fill(255, 0, 0);
    ellipse(centerX, centerY, SMALL_DOT_DIAM, SMALL_DOT_DIAM);
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 3 - DRAW SECOND HAND - PRACTICE TRIG**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// Copy the code from above into the cell below and add a method to draw a second hand.
//
// Create a drawSecond() function, and call it from draw().
//
// In your drawSecond() function, you will want to draw a line from the center of the clock to the edge of the clock. You will want this line to move around the clock.
//
// To make a second hand that moves, you can call the second() method, which is a special function in Processing that will give you the current time, in seconds. This is your source value. You need to scale that using the scale formula:
//
//     dest_val = SRC_MIN + src_val/(SRC_MAX - SRC_MIN) * (DEST_MAX - DEST_MIN)
//
// In this case your src is number of seconds (min is 0, max is 60). Destination is angle around the clock (remember, you want this to be in radians). Use this forumla to calculate the angle of the second hand each time the drawSecond() function is called. Then, use the angle to calcuate the second coordinate set for the line (the coordinates at the edge of the clock).
//
// Once you are done, you should have a clock with a second hand that ticks around it...

// %%
// copy the code from above

// %% [markdown]
// **Step 4 - COPY YOUR WORK TO YOUR TEAM LOCKER**
//
// Save this out to HTML and copy it to your team locker, which you should be able to find under the Communication tab. You can also upload screenshots of the scripts, since images aren't saved with the HTML.
