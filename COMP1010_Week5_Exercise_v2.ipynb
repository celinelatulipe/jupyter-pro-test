// %% [markdown]
// **Week 5**
//
// **Beware that this notebook will expire after 10 minutes of inactivity**
//
// **If it seems like the notebook isn't responding, try Kernel->Restart or Kernel->Reconnect**
//
// **Keep working and frequently copy your code out to an external text file in case the notebook instance disappears**
//
// Objectives:
//
// - Coding Practice!
// - Fill in the correct boolean expressions to make the Processing sketches work
// - Use if statements to change colors depending on key presses
// - Use nested if statements to select colors from a Palette

// %% [markdown]
// Work with **1** partner (not in threes and not by yourself!).
//
// Type your names here: (double-click in this cell to make it editable). This cell uses Markdown so you can make things **bold** or *italic*. When you are done editing this cell, click Run to see your formatting.
//
//     Student 1:
//     Student 2:

// %% [markdown]
// **Step 1 - Boolean Expressions 1**
//
// The script below is almost complete, but the boolean expression in the if statement is missing. Figure out (by reading through the code and comments) what the expression should be.
//
// Here is an output image that shows what the output will look like if you put in the correct expression. (Note that your black border will be at a different vertical location every time you run the code, since it is random)
//
// <img src="images/dot_border1.png" width=300/>
//
// Test yours to make sure you did it right.

// %%
final int DOT_SIZE = 50;
final int BORDER_Y = (int)random(100,400);;

void setup() {
  size(500,500);
  background(230, 200, 50); //yellow
}

void draw() {
  stroke(0); // black
  strokeWeight(8);
  noFill();
  line(0, BORDER_Y, width, BORDER_Y); // horizontal border
  drawDots();
}

void drawDots() {
  noStroke();
  float dotX = random(width);
  float dotY = random(height);
  // the top of the random dot:
  float dotYTop = dotY - DOT_SIZE/2;
  // TODO: fill in a boolean expression in the if statement below
  // only draw blue dots below the black border
  // use the dotYTop variable above and the global borderY variable
  if (dotYTop > BORDER_Y) {
    fill(50,50,random(100,200)); // random shade of blue
    ellipse(dotX, dotY, DOT_SIZE, DOT_SIZE);
  } 
  
}
// Out:
// <div id="canvas_div_6">
//   <b>Sketch #6:</b><br/>
//   <canvas id="canvas_6"></canvas><br/>
// </div>
// <div id="controls_div_6">
//   <button id="run_button_6" onclick="startSketch('6');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_6" onclick="pauseSketch('6');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_6" onclick="setupSketch('6');">
//     setup()
//   </button>
//   <button id="draw_button_6" onclick="drawSketch('6');">
//     draw()
//   </button>
// </div>
// <b>Sketch #6 state:</b> <span id="state_6">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 2 - IF-ELSE**
//
// Copy the code from above into teh cell below and modify it so that if the random dot doesn't fit below the border, it still gets drawn, but now it is a random shade of red. If you do this the simple way, the reddish dots will sometimes overlap the border a bit, like this:
//
// <img src="images/dot_border2.png" width=300/>

// %%
// copy the code from above and then make the appear above the border, but those dots should be reddish

// %% [markdown]
// **Step 3 - IF-ELSE-IF**
// You can also use an if-else-if structure to add another test that ensures the reddish dots fully fit above the border, like this:
//
// <img src="images/dot_border3.png" width=300/>
//
// And, it turns out that this actually looks much more interesting if you don't draw the black border line at all:
//
// <img src="images/dot_border4.png" width=300/>
//
// So, comment out the line of code that draws the black border.

// %%
// copy the code from above and add code to make sure the red dots only appear 
// if they fit fully above the black border line
// Out:
// <div id="canvas_div_1">
//   <b>Sketch #1:</b><br/>
//   <canvas id="canvas_1"></canvas><br/>
// </div>
// <div id="controls_div_1">
//   <button id="run_button_1" onclick="startSketch('1');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_1" onclick="pauseSketch('1');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_1" onclick="setupSketch('1');">
//     setup()
//   </button>
//   <button id="draw_button_1" onclick="drawSketch('1');">
//     draw()
//   </button>
// </div>
// <b>Sketch #1 state:</b> <span id="state_1">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 4 - DOTS IN A BOX**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// Now your job is to draw blue dots only inside a box. All you have to do below is fill in the correct expression in the if statement.

// %%
final int DOT_SIZE = 50;
final int BOX_WIDTH = 300;
final int BOX_HEIGHT = 300;
final int BOX_LEFT = 100;
final int BOX_TOP = 100;
final int BOX_RIGHT = BOX_LEFT + BOX_WIDTH;
final int BOX_BOTTOM = BOX_TOP + BOX_HEIGHT;

void setup() {
  size(500,500);
  background(230, 200, 50); // yellow
}

void draw() {
  stroke(0); // black
  strokeWeight(8);
  noFill();
  //rect(BOX_LEFT,BOX_TOP,BOX_WIDTH,BOX_HEIGHT); // big square centered in canvas
  drawDots();
}

void drawDots() {
  noStroke();
  float dotX = random(width);
  float dotY = random(height);
  
  float dotXLeft = dotX - DOT_SIZE/2;
  float dotXRight = dotX + DOT_SIZE/2;
  float dotYTop = dotY - DOT_SIZE/2;
  float dotYBottom = dotY + DOT_SIZE/2;
  // TODO: fill in a boolean expression in the if statement below
  // only draw blue dots that will fit completely inside the black box
  // use the four dot variables above and the global box constants to write the boolean expression
  if (dotXLeft > BOX_LEFT && dotXRight < BOX_RIGHT && dotYTop > BOX_TOP && dotYBottom < BOX_BOTTOM) {
    fill(50,50,random(100,200)); // blue
    ellipse(dotX, dotY, DOT_SIZE, DOT_SIZE);
  } 
  
}
// Out:
// <div id="canvas_div_5">
//   <b>Sketch #5:</b><br/>
//   <canvas id="canvas_5"></canvas><br/>
// </div>
// <div id="controls_div_5">
//   <button id="run_button_5" onclick="startSketch('5');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_5" onclick="pauseSketch('5');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_5" onclick="setupSketch('5');">
//     setup()
//   </button>
//   <button id="draw_button_5" onclick="drawSketch('5');">
//     draw()
//   </button>
// </div>
// <b>Sketch #5 state:</b> <span id="state_5">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 5 - Conditions with Mouse Input**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**

// %%
// copy the code from above and then draw an empty square centered on canvas, enclosing the cursor
// Out:
// <div id="canvas_div_6">
//   <b>Sketch #6:</b><br/>
//   <canvas id="canvas_6"></canvas><br/>
// </div>
// <div id="controls_div_6">
//   <button id="run_button_6" onclick="startSketch('6');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_6" onclick="pauseSketch('6');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_6" onclick="setupSketch('6');">
//     setup()
//   </button>
//   <button id="draw_button_6" onclick="drawSketch('6');">
//     draw()
//   </button>
// </div>
// <b>Sketch #6 state:</b> <span id="state_6">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 6 - Conditions with Keyboard Input**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**

// %%
// copy code from above and then change the max() and min() calls for the dot locations 
// so that instead of staying within the canvas, they stay within the enclosing square
// Out:
// <div id="canvas_div_11">
//   <b>Sketch #11:</b><br/>
//   <canvas id="canvas_11"></canvas><br/>
// </div>
// <div id="controls_div_11">
//   <button id="run_button_11" onclick="startSketch('11');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_11" onclick="pauseSketch('11');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_11" onclick="setupSketch('11');">
//     setup()
//   </button>
//   <button id="draw_button_11" onclick="drawSketch('11');">
//     draw()
//   </button>
// </div>
// <b>Sketch #11 state:</b> <span id="state_11">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
// ...

// %% [markdown]
// **Step 6 - BONUS - Make a moon orbit around the earth, which is orbiting the sun**
//
// The code below generates an abstract space scene in which earth is orbiting the sun, while stars flash by in the background. Run the code to see it work, and then your job is to add constants and variables to make a moon orbit the earth. You will want to inspect the code to understand how it works. Note that we use the trig functions sin() and cos() to calculate the position of the earth with respect to the moon, using the EARTH_DIST constant, to keep the orbit the same all the way around. Note how the speed of the orbit is controlled by EARTH_SPEED (which just slighlty increments the orbit angle during each call to draw()).
//
// To complete this bonus, you need to make a function that draws a white moon that is smaller in size than the earth, and that orbits the earth (the way the earth orbits the sun). The moon should orbit the earth faster than the earth orbits the sun. The moon should be close to the earth. Make sure to create constants and variables that have good names.
//
// Your moon orbiting the earth should look something like this:
//
// <img src="images/moon.png" width=300 />

// %%
final int CENTERX = 250;
final int CENTERY = 250;
final int SUN_DIAM = 70;
final int EARTH_DIAM = 50;
final int EARTH_DIST = 150; // distance from sun
final float EARTH_SPEED = 0.01;
float earthAngle = 0.0; // angle of earth from sun
float earthX, earthY;

void setup() {
  size(500,500);

}

void draw() {
  background(0);
  
  drawStars();
  drawSun();
  drawEarth();
  
}

void drawStars() {
  stroke(255); // white
  strokeWeight(3);
  point(random(width), random(height));
  point(random(width), random(height));
  point(random(width), random(height));
  point(random(width), random(height));
}

void drawSun() {
  fill(255, 200, 100); // yellowish
  noStroke();
  ellipse(width/2, height/2, SUN_DIAM, SUN_DIAM);
}

void drawEarth() {
  fill(100, 100, 250); // blueish
  earthX = CENTERX + cos(earthAngle)*EARTH_DIST;
  earthY = CENTERY + sin(earthAngle)*EARTH_DIST;
  ellipse(earthX, earthY, EARTH_DIAM, EARTH_DIAM);
  earthAngle = earthAngle + EARTH_SPEED;
}
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// ...

// %% [markdown]
// **Step 7 - COPY YOUR WORK TO YOUR TEAM LOCKER**
//
// Save this out to HTML and copy it to your team locker, which you should be able to find under the Communication tab. You can also upload screenshots of the scripts, since images aren't saved with the HTML.
