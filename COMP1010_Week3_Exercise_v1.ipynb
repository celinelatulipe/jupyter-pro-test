// %% [markdown]
// **Week 3**
//
// **Beware that this notebook will expire after 10 minutes of inactivity**
//
// **If it seems like the notebook isn't responding, try Kernel->Restart or Kernel->Reconnect**
//
// **Keep working and frequently save using the save button at the top (don't use Save as...)**

// %% [markdown]
// Work with **1** partner (not in threes and not by yourself!).
//
// Type your names here: (double-click in this cell to make it editable). This cell uses Markdown so you can make things **bold** or *italic*. When you are done editing this cell, click Run to see your formatting.
//
//     Student 1:
//     Student 2:

// %% [markdown]
// **Step 1 - Robot resizable!**
//
// Let's get started! In the block below is Dr. Celine's robot head from Week 2. Run this to see what the robot looks like. Change the canvas size() and run it again to make sure the robot resizes appropriately.

// %%
/** 
Dr. Celine's Robot Head
**/
// global vars
size(500,500);
int headWidth = width*2/3;
int headHeight = height/3;
int headTop = (height - headHeight)/3;
int headLeft = (width - headWidth)/2;

int leftEyeX = headLeft + headWidth/4;
int rightEyeX = headLeft + headWidth*3/4;
int eyeY = headTop + headHeight/3;
int eyeDiam = headWidth/5;
int eyeBallDiam = eyeDiam/2;

int mouthLeft = leftEyeX;
int mouthRight = rightEyeX;
int mouthY = headTop + headHeight*3/4;


background(100, 100, 250);

// draw head
fill(200, 200, 50);
rect(headLeft, headTop, headWidth, headHeight);

// draw eyes
fill(255);
ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

// draw eyeballs
fill(0);
ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


// draw mouth
stroke(200, 100, 100);
strokeWeight(8);
line(mouthLeft, mouthY, mouthRight, mouthY);
// Out:
// <div id="canvas_div_8">
//   <b>Sketch #8:</b><br/>
//   <canvas id="canvas_8"></canvas><br/>
// </div>
// <div id="controls_div_8">
//   <button id="run_button_8" onclick="startSketch('8');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_8" onclick="pauseSketch('8');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_8" onclick="setupSketch('8');">
//     setup()
//   </button>
//   <button id="draw_button_8" onclick="drawSketch('8');">
//     draw()
//   </button>
// </div>
// <b>Sketch #8 state:</b> <span id="state_8">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = "/** \nDr. Celine's Robot Head\n**/\nsize(500,500);\nbackground(100, 100, 250);\n\nint headWidth = width*2/3;\nint headHeight = height/3;\nint headTop = (height - headHeight)/3;\nint headLeft = (width - headWidth)/2;\n\nint leftEyeX = headLeft + headWidth/4;\nint rightEyeX = headLeft + headWidth*3/4;\nint eyeY = headTop + headHeight/3;\nint eyeDiam = headWidth/5;\nint eyeBallDiam = eyeDiam/2;\n\nint mouthLeft = leftEyeX;\nint mouthRight = rightEyeX;\nint mouthY = headTop + headHeight*3/4;\n\n\n// draw head\nfill(200, 200, 50);\nrect(headLeft, headTop, headWidth, headHeight);\n\n// draw eyes\nfill(255);\nellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye\nellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye\n\n// draw eyeballs\nfill(0);\nellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye\nellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye\n\n\n// draw mouth\nstroke(200, 100, 100);\nstrokeWeight(8);\nline(mouthLeft, mouthY, mouthRight, mouthY);";
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_8").innerHTML = e.toString();
//         document.getElementById("state_8").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_8", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_8").innerHTML = e.toString();
//             document.getElementById("state_8").style.color = "red";
//             processingInstance = new Processing("canvas_8", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_8").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_8").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("st

// %% [markdown]
// **Step 2 - Turn this into an active Processing script**
//
// Turn this into an Active processing script by putting the size() command in a setup() function and the drawing functions in a draw() function. Note that you are going to have to put variable declarations as globals at the top, and then initialize all the variable values inside setup(). Once you have done this, run the program to make sure you still see the same robot.

// %%
// global vars
size(500,500);
int headWidth = width*2/3;
int headHeight = height/3;
int headTop = (height - headHeight)/3;
int headLeft = (width - headWidth)/2;

int leftEyeX = headLeft + headWidth/4;
int rightEyeX = headLeft + headWidth*3/4;
int eyeY = headTop + headHeight/3;
int eyeDiam = headWidth/5;
int eyeBallDiam = eyeDiam/2;

int mouthLeft = leftEyeX;
int mouthRight = rightEyeX;
int mouthY = headTop + headHeight*3/4;


background(100, 100, 250);

// draw head
fill(200, 200, 50);
rect(headLeft, headTop, headWidth, headHeight);

// draw eyes
fill(255);
ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

// draw eyeballs
fill(0);
ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


// draw mouth
stroke(200, 100, 100);
strokeWeight(8);
line(mouthLeft, mouthY, mouthRight, mouthY);
// Out:
// <div id="canvas_div_2">
//   <b>Sketch #2:</b><br/>
//   <canvas id="canvas_2"></canvas><br/>
// </div>
// <div id="controls_div_2">
//   <button id="run_button_2" onclick="startSketch('2');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_2" onclick="pauseSketch('2');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_2" onclick="setupSketch('2');">
//     setup()
//   </button>
//   <button id="draw_button_2" onclick="drawSketch('2');">
//     draw()
//   </button>
// </div>
// <b>Sketch #2 state:</b> <span id="state_2">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = 'size(300,300);\nbackground(0);\nrect(50, 50, 200, 100);\n// write code below here to add eyes (2 ellipses) and a mouth (a straight line)\nellipse(120, 100, 30, 30);\nellipse(180, 100, 30, 30);\nline(100, 130, 200, 130);';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_2").innerHTML = e.toString();
//         document.getElementById("state_2").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_2", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_2").innerHTML = e.toString();
//             document.getElementById("state_2").style.color = "red";
//             processingInstance = new Processing("canvas_2", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_2").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_2").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_2").innerHTML = "Running...";
//                 document.getElementById("state_2").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_2"), true);
//             change_button(document.getElementById("pause_button_2"), false);
//             change_button(document.getElementById("setup_button_2"),  true);
//             change_button(document.getElementById("draw_button_2"), true);
//         } else {
//             if (!has_error) {
//                 document.getElementById("state_2").innerHTML = "Done.";
//                 document.getElementById("state_2").style.color = "blue";
//             }
//             change_button(document.getElementById("run_button_2"), true);
//             change_button(document.getElementById("pause_button_2

// %% [markdown]
// **Step 3 - Add interaction**
//
// Make your script better by adding a moving circle that follows the mouse cursor, in front of the robot. Copy your code from above, and add the following two global int variables, flyX and flyY. In setup() initialize these both to 0.
//
// In the draw funtion, after the commands that draw the robot face, add a an ellipse command that draws a small circle wherever the mouse is. Add two-three other draw commands that make the circle look like a fly.

// %%
// global vars


int headWidth;
int headHeight;
int headTop;
int headLeft;

int leftEyeX;
int rightEyeX;
int eyeY;
int eyeDiam;
int eyeBallDiam;

int mouthLeft;
int mouthRight;
int mouthY;

void setup() {
size(500,500);
    headWidth = width*2/3;
    headHeight = height/3;
    headTop = (height - headHeight)/3;
    headLeft = (width - headWidth)/2;

    leftEyeX = headLeft + headWidth/4;
    rightEyeX = headLeft + headWidth*3/4;
    eyeY = headTop + headHeight/3;
    eyeDiam = headWidth/5;
    eyeBallDiam = eyeDiam/2;

    mouthLeft = leftEyeX;
    mouthRight = rightEyeX;
    mouthY = headTop + headHeight*3/4;
}

void draw() {}
    background(100, 100, 250);

    // draw head
    fill(200, 200, 50);
    rect(headLeft, headTop, headWidth, headHeight);

    // draw eyes
    fill(255);
    ellipse(leftEyeX, eyeY, eyeDiam, eyeDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeDiam, eyeDiam); // right eye

    // draw eyeballs
    fill(0);
    ellipse(leftEyeX, eyeY, eyeBallDiam, eyeBallDiam); // left eye
    ellipse(rightEyeX, eyeY, eyeBallDiam, eyeBallDiam); // right eye


    // draw mouth
    stroke(200, 100, 100);
    strokeWeight(8);
    line(mouthLeft, mouthY, mouthRight, mouthY);
}

// %% [markdown]
// **Step 4 - ADD COLOUR!**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// This robot is pretty boring. Copy your code from above into the cell below. Then, add colour! Change the robot head colour (use the fill command). Also add eyeballs (smaller, black ellipses) centered in the eyes. Then make the mouth line thicker (use the strokeWeight command). Change the colour of the mouth (use the stroke command). You can also change the background colour.

// %%
// copy code from above to this cell.
// Make the robot head a different colour.
// Add black eyeballs (or some other colour eyeballs)
// Make the mouth a different colour, and thicker.
// Change the background colour if you want to.

// %% [markdown]
// **Step 5 - USE VARIABLES!**
//
// In the cell below, copy the code from above. Then, add two variables for headWidth and headHeight. These should be int variables and they should be set to width\*2/3 and height/3.  This way the robot's head will always be 2/3 the width of the canvas, and one third the height of the canvas.
//
// Then, add two more variables for headTop and headLeft. These variables should be set like this:
//
//     int headTop = (height - headHeight)/3;
//
//     int headLeft = (width - headWidth)/2;
//
// Now, rewrite your rect command to use these four variables.

// %%
// copy code from above to this cell
// add variables for the robot head, putting the variable declarations at the top, after the size() command
// make use of the variables in the rect() command
// Out:
// <div id="canvas_div_4">
//   <b>Sketch #4:</b><br/>
//   <canvas id="canvas_4"></canvas><br/>
// </div>
// <div id="controls_div_4">
//   <button id="run_button_4" onclick="startSketch('4');">
//     <i class="fa fa-play-circle-o" style="size: 2em;"></i>
//         Run
//   </button>
//   <button id="pause_button_4" onclick="pauseSketch('4');">
//     <i class="fa fa-pause" style="size: 2em;"></i>
//         Pause
//   </button>
//   <button id="setup_button_4" onclick="setupSketch('4');">
//     setup()
//   </button>
//   <button id="draw_button_4" onclick="drawSketch('4');">
//     draw()
//   </button>
// </div>
// <b>Sketch #4 state:</b> <span id="state_4">Loading...</span><br/>
// <script>
//
// function change_button(button, disable) {
//     button.disabled = disable;
//     if (disable) {
//         button.style.color = "grey";
//     } else {
//         button.style.color = "black";
//     }
// }
//
// function startSketch(id) {
//     switchSketchState(id, true);
// }
//
// function pauseSketch(id) {
//     switchSketchState(id, false);
// }
//
// function drawSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.draw != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Drawing...";
//             try {
//                 processingInstance.redraw();
//                 document.getElementById("state_" + id).innerHTML = "Drawing... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No drawing() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function setupSketch(id) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (processingInstance != undefined) {
//         if (processingInstance.setup != undefined) {
//             document.getElementById("state_" + id).innerHTML = "Setting up...";
//             try {
//                 processingInstance.setup();
//                 document.getElementById("state_" + id).innerHTML = "Setting up... done! Paused.";
//                 document.getElementById("state_" + id).style.color = "blue";
//             } catch (e) {
//                 processingInstance.println(e.toString());
//                 document.getElementById("state_" + id).innerHTML = e.toString();
//                 document.getElementById("state_" + id).style.color = "red";
//             }
//         } else {
//             document.getElementById("state_" + id).innerHTML = "No setup() function. Paused.";
//             document.getElementById("state_" + id).style.color = "blue";
//         }
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Error.";
//         document.getElementById("state_" + id).style.color = "red";
//     }
//     change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//     change_button(document.getElementById("pause_button_" + id), true);
//     change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//     change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
// }
//
// function switchSketchState(id, on) {
//     var processingInstance = Processing.getInstanceById("canvas_" + id);
//     if (on) {
//         document.getElementById("state_" + id).innerHTML = "Running...";
//         document.getElementById("state_" + id).style.color = "green";
//         change_button(document.getElementById("run_button_" + id), true);
//         change_button(document.getElementById("pause_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("setup_button_" + id),  true);
//         change_button(document.getElementById("draw_button_" + id), true);
//         processingInstance.loop();  // call Processing loop() function
//     } else {
//         document.getElementById("state_" + id).innerHTML = "Paused.";
//         document.getElementById("state_" + id).style.color = "blue";
//         change_button(document.getElementById("run_button_" + id), processingInstance.draw == undefined);
//         change_button(document.getElementById("pause_button_" + id), true);
//         change_button(document.getElementById("setup_button_" + id), processingInstance.setup == undefined);
//         change_button(document.getElementById("draw_button_" + id), processingInstance.draw == undefined);
//         processingInstance.noLoop(); // stop animation, call noLoop()
//     }
// }
//
// require([window.location.protocol + "//calysto.github.io/javascripts/processing/processing.js"], function () {
//     var processingCode = '// copy code from above to this cell\n// add variables for the robot head\nsize(500,500);\nbackground(100, 100, 250);\n\nint headWidth = width*2/3;\nint headHeight = height/3;\nint headTop = (height - headHeight)/3;\nint headLeft = (width - headWidth)/2;\nfill(200, 200, 50);\nrect(headLeft, headTop, headWidth, headHeight);\n// write code below here to add eyes (2 ellipses) and a mouth (a straight line)\n\nfill(255);\nellipse(120, 100, 30, 30);\nellipse(180, 100, 30, 30);\n\nfill(0);\nellipse(120, 100, 10, 10);\nellipse(180, 100, 10, 10);\n\nstroke(200, 100, 100);\nstrokeWeight(8);\nline(100, 130, 200, 130);';
//     var cc;
//     var processingInstance;
//     var has_error = false;
//
//     try {
//         cc = Processing.compile(processingCode);
//     } catch (e) {
//         console.log(e);
//         cc = Processing.compile("println('" + e.toString() + "');");
//         document.getElementById("state_4").innerHTML = e.toString();
//         document.getElementById("state_4").style.color = "red";
//         has_error = true;
//     }
//     if (cc != undefined) {
//         try {
//             processingInstance = new Processing("canvas_4", cc);
//             processingInstance.println = window.jyp_println
//         } catch (e) {
//             console.log(e);
//             cc = Processing.compile("println('" + e.toString() + "');");
//             document.getElementById("state_4").innerHTML = e.toString();
//             document.getElementById("state_4").style.color = "red";
//             processingInstance = new Processing("canvas_4", cc);
//             processingInstance.println = window.jyp_println
//             has_error = true;
//         }
//     }
//     if (processingInstance != undefined) {
//         setTimeout(function () {
//             // Canvas:
//             if (processingInstance.externals.context === undefined) {
//                 document.getElementById("canvas_div_4").style.display = "none";
//             }
//         }, 100);
//         // Controls:
//         if (!(processingInstance.isRunning() && processingInstance.draw != undefined)) {
//             document.getElementById("controls_div_4").style.display = "none";
//         }
//         if (processingInstance.draw != undefined) {
//             if (!has_error) {
//                 document.getElementById("state_4").innerHTML = "Running...";
//                 document.getElementById("state_4").style.color = "green";
//             }
//             change_button(document.getElementById("run_button_4"), true);
//             change_button(document.getElementById("pause_button_4"), false);
//             change_button(document.getElementById("setup_button_4"),  true);
//             change_button

// %% [markdown]
// **Step 5a - TEST VARIABLES!**
//
// If your variables are set up correctly, the robot head should expand if you make the canvas bigger. Test this by changing the Canvas size above to 500, 500. You should see something like this (the robot head is bigger, but now the eyes don't quite fit and the mouth is also in the wrong place). Note that your version will have different colours.
//
// <img src="images/headScale.png" width="200" />

// %% [markdown]
// **Step 6 - MORE VARIABLES**
//
// Copy the code above into the cell below. Add more variables for the robot, so that the eyes scale with the canvas. I suggest adding the following variables:
//
// leftEyeX, leftEyeY, rightEyeX, rightEyeY, eyeWidth, eyeBallWidth.
//
// Figure out what each should be set to (make sure they are relative to either the robot head or the canvas width and height, so that if the canvas size changes the eyes move appropriately.
//
// Test this! Change the canvas size a few times to make sure the eyes are moving around appropriately.

// %%
//copy code from above and then add and use variables for eye position & size

// %% [markdown]
// **Step 7 - MORE VARIABLES**
//
// **SWITCH WHO IS CONTROLLING THE KEYBOARD - GIVE THE COMPUTER TO YOUR PARTNER**
//
// Copy the code above into the cell below. Add more variables for the robot, so that the mouth scales with the canvas. Come up with good variable names for the width and position of the mouth.
//
// Figure out what each variable should be set to (make sure they are relative to either the robot head or the canvas width and height, so that if the canvas size changes, the mouth moves appropriately).
//
// Test this! Change the canvas size a few times to make sure the mouth moves around appropriately.

// %%
//copy code from above and then add and use variables for mouth position & size

// %% [markdown]
// **Step 8 - CONSTANTS!**
//
// Okay, so in actual fact, all of the things we have created so far are CONSTANTS, not variables. How do you know? Well, because each of them gets assigned only once during the program and the values don't change while the program is running.
//
// So, I hate to do this to you, but I want you to copy your program above, and add the keyword final in front of all your declarations, and change the code to be the correct style (ALL_CAPS). As an example, these:
//
//     int headHeight = height/3;
//
//     int headWidth = width\*2/3;
//
//     int headTop = (height - headHeight)/3;
//
//     int headLeft = (width - headWidth)/2;
//
// should be replaced by these:
//
//     final int HEAD_HEIGHT = height/3;
//
//     final int HEAD_WIDTH = width\*2/3;
//
//     final int HEAD_TOP = (height - HEAD_HEIGHT)/3;
//
//     final int HEAD_LEFT = (width - HEAD_WIDTH)/2;
//
// Once you are done making all the changes, run your code to make sure it is still working.

// %%
// copy above and change all your variables to CONSTANTS. Use appropriate capitalization. 
// You will have to change the variables throughout your code

// %% [raw]
// **Step 9 - COPY YOUR FINAL ROBOT IMAGE AND CODE TO YOUR TEAM WORKSPACE**
//
// Well, you are basically done. What do you do now? Save this notebook. I suggest downloading it as HTML. Your images will not show up, but all the code you wrote will be there and you will be able to see the progression of what you did.
//
// Once you have downloaded the HTML, upload the file to your team workspace on UMLearn. Alternatively, you can take screenshots and upload those to document your work. Make sure you add your names to the filename before uploading, so that when multiple people in your group add their's, you can differentiate.
//
// *You can also save it out as a Jupyter Notebook file (.ipynb), and if you install Jupyter notebooks, you can open that locally. (Note that installing Jupyter Notebooks is NOT easy at all - it's something for experienced sys admin type people, and may be well beyond your skill level - it took Dr. Celine awhile to get it working on her Mac).
